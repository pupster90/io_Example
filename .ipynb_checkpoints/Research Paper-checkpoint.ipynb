# %% [markdown]
# **<div class="text-center"><font size=8>ATC Tumorigenesis Analysis</font></div>**

# %% [markdown]
# **<div class="text-center"><font size=4>Abstract</font></div>**

# %% [markdown]
# <div class="text-center" style="padding-left: 6em; padding-right: 7em;">
# We are the music makers and we are the dreamers of dreams. We are the music makers and we are the dreamers of dreams. We are the music makers and we are the dreamers of dreams. We are the music makers and we are the dreamers of dreams. We are the music makers and we are the dreamers of dreams. We are the music makers and we are the dreamers of dreams.
# </div>

# %% [markdown]
# # Introduction

# %% [markdown]
# We are the music makers and we are the dreamers of dreams. We are the music makers and we are the dreamers of dreams. We are the music makers and we are the dreamers of dreams. We are the music makers and we are the dreamers of dreams. We are the music makers and we are the dreamers of dreams. We are the music makers and we are the dreamers of dreams.

# %% [markdown]
# $$
# \text{visitable}(e)=\begin{cases} \text{True} & \text{if}\quad\text{departure}(e)-15\geq\text{dist}(u)\quad\leftarrow\text{where }e=(u,v)\\ \text{False} & \quad\text{otherwise} \end{cases}
# $$

# %% [markdown]
# # ATC Graph

# %% [markdown]
# We are the music makers and we are the dreamers of dreams. We are the music makers and we are the dreamers of dreams. We are the music makers and we are the dreamers of dreams. We are the music makers and we are the dreamers of dreams. We are the music makers and we are the dreamers of dreams. We are the music makers and we are the dreamers of dreams.

# %%
# %run "~/Apps/io_View/embed.ipynb"
def embedFile(file_name, size="medium"):
    sizes = {'small':"col-md-offset-4 col-md-4", 'medium':"col-md-offset-3 col-md-6", 'large':"col-md-offset-2 col-md-8"}
    my_size = sizes[size]
    display(HTML(f"""
    <div class="row"><div class="col-xs-12 {my_size}">
    <div class="embed-responsive embed-responsive-16by9" style='border-style: solid;border-width: 1px;'>
      <iframe class="embed-responsive-item" 
      src='{file_name}'></iframe></div>
    </div></div>
    """))
embedFile("index.html", "large")

# %% [markdown]
# # Cytokine Analysis

# %% [markdown]
# We are the music makers and we are the dreamers of dreams. We are the music makers and we are the dreamers of dreams. We are the music makers and we are the dreamers of dreams. We are the music makers and we are the dreamers of dreams. We are the music makers and we are the dreamers of dreams. We are the music makers and we are the dreamers of dreams.

# %% [markdown]
# **Useful Link:** [Scatter Plot Example](https://matplotlib.org/3.1.1/gallery/shapes_and_collections/scatter.html)

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact
@interact( Cytokine=(1, 8), ) 
def f(Cytokine):
    checkit=Cytokine
    N = 50
    x = np.random.rand(N)
    y = np.random.rand(N)
    colors = np.random.rand(N)
    area = (30 * np.random.rand(N))**2  # 0 to 15 point radii
    
    plt.scatter(x, y, s=area, c=colors, alpha=0.5 )
    plt.title(f"Cytokine {checkit}")
    plt.show()
